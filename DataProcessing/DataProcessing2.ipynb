# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from matplotlib import font_manager

# %% [markdown]
# 한글폰트설정

# %%
font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
font_name = font_manager.FontProperties(fname=font_location).get_name()
mpl.rc('font', family=font_name)

# %% [markdown]
# Data Read

# %%
path='Data/'
file_list=os.listdir(path)
file_list
# Out:
# ['2012_2014.csv', '2015.csv', '2016.csv', '2017.csv', '2018.csv']

# %%
char=['발생년', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
       '부상신고자수', '발생지시도',  '사고유형_대분류', '법규위반_대분류',
       '도로형태_대분류', '가해자_당사자종별_대분류', '피해자_당사자종별_대분류']
col=['년도', '주야', '요일', '사망자수', '사상자수', '중상자수', '경상자수',
       '부상자수', '발생지', '사고유형', '법규위반',
       '도로형태', '가해자', '피해자']

# %%
data=[]
for i in file_list :
    print(i);
    d=pd.read_csv(path+i,  encoding = 'utf-8')
    d=d.dropna()
    d=d[char]
    d.columns=col
    data.append(d)
# Out:
# 2012_2014.csv
# 2015.csv
# 2016.csv
# 2017.csv
# 2018.csv

# %%
data[4]
# Out:
#         년도 주야 요일  사망자수  사상자수  중상자수  경상자수  부상자수 발생지  사고유형     법규위반 도로형태  가해자  \
# 0     2018  주  수     1     1     0     0     0  서울  차대사람  운전자법규위반  단일로  승용차
# 1     2018  야  일     1     1     0     0     0  서울  차대사람  운전자법규위반  교차로  승용차
# 2     2018  야  토     1     1     0     0     0  서울  차량단독  운전자법규위반  단일로  이륜차
# 3     2018  주  목     1     1     0     0     0  서울  차량단독  운전자법규위반  단일로  승합차
# 4     2018  야  월     1     1     0     0     0  서울  차대사람  운전자법규위반  교차로  화물차
# ...    ... .. ..   ...   ...   ...   ...   ...  ..   ...      ...  ...  ...
# 3652  2018  야  월     1     1     0     0     0  경기  차량단독  운전자법규위반  단일로  승용차
# 3653  2018  주  금     1     1     0     0     0  경기   차대차  운전자법규위반  단일로  화물차
# 3654  2018  주  토     1     1     0     0     0  경기  차량단독  운전자법규위반  단일로  승용차
# 3655  2018  야  토     1     1     0     0     0  경기   차대차  운전자법규위반  단일로  승용차
# 3656  2018  주  월     1     2     0     1     0  경기   차대차  운전자법규위반  단일로  승용차
#
#       피해자
# 0     보행자
# 1     보행자
# 2      없음
# 3      없음
# 4     보행자
# ...   ...
# 3652   없음
# 3653  농기계
# 3654   없음
# 3655  승용차
# 3656  승용차
#
# [3657 rows x 14 columns]

# %% [markdown]
# 가설 1 -

# %% [markdown]
# 가설 2 -
